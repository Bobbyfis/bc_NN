# %%
import torch

# load one file
data = torch.load('data/mega_train_embeddings/r10_437_TrROS_Hall.pdb_E1Q.pt')

# see what keys it has
print(data.keys())

# see the full structure
print(data)
len(data['mean_representations'][6])
# Out:
# dict_keys(['label', 'mean_representations'])
# {'label': 'r10_437_TrROS_Hall.pdb_E1Q', 'mean_representations': {6: tensor([ 4.6533e-01, -1.2226e-01, -1.5722e-01, -1.9923e-01, -6.6079e-01,
#          1.3585e-01, -1.7845e-01,  1.2354e+00, -8.1173e-01, -4.5385e-01,
#         -6.8757e-01, -2.2396e-01,  3.7292e-02,  3.1087e-01, -5.6775e-01,
#         -7.9119e-01,  5.3996e-01, -6.3942e-01, -4.5017e-01,  7.2143e-01,
#          1.1921e-01, -2.8448e-01,  7.0431e-02,  4.9931e-01,  8.7709e-01,
#          1.3525e-01, -1.6536e-01, -1.1097e-01,  6.2955e-01, -9.3916e-01,
#          2.3629e-02, -3.2584e-01,  4.0978e-01,  1.3659e+00, -4.9318e-01,
#          6.9619e-01, -2.6866e-01,  7.0479e-02, -8.3463e-01,  3.2833e-01,
#          1.7035e-01,  8.4833e-01, -1.3573e-01, -3.1289e-01,  4.9321e-02,
#          2.4549e-01, -6.6376e-01,  3.0518e-01,  1.4302e-01,  2.8468e-02,
#          5.6711e-01,  1.9296e-01,  5.3238e-01,  1.4605e+00, -5.9578e-01,
# ...
